# %% [markdown]
# ## 영상의 크기 변환

# %% [markdown]
# ![image.png](attachment:3ff50d80-1b96-44c8-8bbf-f7cc9080c9ec.png)

# %% [markdown]
# ![image.png](attachment:54966b1b-c31a-4cb9-bcbc-2fe71cd9db76.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/rose.bmp')

# %%
if src is None:
    print('Image load failed!')
    sys.exit()

# %%
dst1 = cv2.resize(src,(0,0), fx=4, fy=4, interpolation=cv2.INTER_NEAREST)
dst2 = cv2.resize(src,(1920,1280))
dst3 = cv2.resize(src, (1920,1280), interpolation = cv2.INTER_CUBIC)
dst4 = cv2.resize(src, (1920,1280), interpolation = cv2.INTER_LANCZOS4)

# %%
cv2.imshow('src', src)
cv2.imshow('dst1', dst1[500:900, 400:800])
cv2.imshow('dst2', dst2[500:900, 400:800])
cv2.imshow('dst3', dst3[500:900, 400:800])
cv2.imshow('dst4', dst4[500:900, 400:800])
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:fd8eebff-e299-49e1-8cfc-c83f7c297d5c.png)
