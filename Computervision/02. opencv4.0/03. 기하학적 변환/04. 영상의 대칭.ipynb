# %% [markdown]
# ## 영상의 대칭
# - 좌우 대칭, 상하 대칭, 좌우&상하 대칭

# %% [markdown]
# ![image.png](attachment:cbba0aa6-a61d-42b6-8d4d-c78c21334e07.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/rose.bmp')

# %%
dst = cv2.flip(src, -1)

# %%
cv2.imshow('src', src)
cv2.imshow('dst',dst)
cv2.waitKey()
cv2.destroyAllWindows()
