# %% [markdown]
# ## 어파인 변환과 투시 변환

# %% [markdown]
# ![image.png](attachment:4b81abc0-ac96-4a00-8aaf-ed900cfd13a1.png)

# %% [markdown]
# ![image.png](attachment:3859cae8-821f-4d97-ab78-59e3437dbcb0.png)

# %% [markdown]
# ![image.png](attachment:5f4a2c42-fc64-4c41-8c77-cd7a7c1377d8.png)

# %% [markdown]
# ![image.png](attachment:b86e475f-360b-4b20-9851-4f4f7dd483b1.png)

# %% [markdown]
# ![image.png](attachment:38fec176-8fc2-4997-9b69-f6732259fe2e.png)

# %% [markdown]
# ![image.png](attachment:56cbc7a2-e4cc-40cf-9e25-392357500ff3.png)

# %% [markdown]
# ## 투시 변환

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/namecard.jpg')

# %%
if src is None:
    print('Image load failed')
    sys.exit()

# %%
w, h = 720, 400

# %%
srcQuad = np.array([[325, 307], [760, 369], [718, 611], [231, 515]], np.float32)
dstQuad = np.array([[0, 0], [w-1, 0], [w-1, h-1], [0, h-1]], np.float32)

# %%
pers = cv2.getPerspectiveTransform(srcQuad, dstQuad)
dst = cv2.warpPerspective(src, pers, (w,h))

# %%
cv2.imshow('src', src)
cv2.imshow('dst', dst)
cv2.waitKey()
cv2.destroyAllWindows()
