# %% [markdown]
# ![image.png](attachment:e14d5d08-d06e-47aa-8627-148a6db4209a.png)

# %% [markdown]
# ![image.png](attachment:30d273fe-8bc0-4ae6-a6eb-2d79ff022131.png)

# %% [markdown]
# ![image.png](attachment:f7c8e7ac-53f0-4361-a201-c21268bee46f.png)

# %% [markdown]
# ![image.png](attachment:742cae2a-05fe-426b-8bf8-8397645d197f.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/lenna.bmp', cv2.IMREAD_GRAYSCALE)

# %%
if src is None:
    print('Image load failed!')
    sys.exit()

# %%
dx = cv2.Sobel(src, cv2.CV_32F, 1, 0)
dy = cv2.Sobel(src, cv2.CV_32F, 0, 1)

# %%
mag = cv2.magnitude(dx, dy)
mag = np.clip(mag, 0, 255).astype(np.uint8)

# %%
dst = np.zeros(src.shape[:2], np.uint8)

# %%
dst[mag > 120] = 255

# %%
cv2.imshow('src', src)
cv2.imshow('mag', mag)
cv2.imshow('dst', dst)
cv2.waitKey()

cv2.destroyAllWindows()
