# %% [markdown]
# ![image.png](attachment:6e6af36f-84b8-4a3f-ac9c-81a06cc0507c.png)

# %% [markdown]
# ![image.png](attachment:97790c2f-0dca-4e69-a271-1711cad7c9e4.png)

# %% [markdown]
# ![image.png](attachment:c5d85516-9d6f-4496-b26c-f2e20f893248.png)

# %% [markdown]
# ![image.png](attachment:1bfd09e6-8615-44fa-bab2-724398be2400.png)

# %% [markdown]
# ![image.png](attachment:302772f4-aa50-4eb6-9433-3a0fd74e60e5.png)

# %% [markdown]
# ![image.png](attachment:79237d22-d9cf-48d6-a80d-971b7b4358d9.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/building.jpg', cv2.IMREAD_GRAYSCALE)

# %%
if src is None:
    print('Image load failed!')
    sys.exit()

# %%
dst = cv2.Canny(src, 50, 150)

# %%
cv2.imshow('src', src)
cv2.imshow('dst', dst)
cv2.waitKey()

cv2.destroyAllWindows()
