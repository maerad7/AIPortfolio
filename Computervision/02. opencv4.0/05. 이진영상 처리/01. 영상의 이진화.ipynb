# %% [markdown]
# ![image.png](attachment:63830b2a-5b0b-4726-a221-d5503dce275d.png)

# %% [markdown]
# ![image.png](attachment:e42e4abf-dce0-40b1-8f21-834887ba660c.png)

# %% [markdown]
# ![image.png](attachment:b5ce68c3-b019-4501-8ea7-e8e96ce234d9.png)

# %% [markdown]
# ![image.png](attachment:064fd895-afee-4c3d-9296-cc27a58d3904.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/cells.png', cv2.IMREAD_GRAYSCALE)

# %%
if src is None:
    print('Image load failed!')
    sys.exit()

# %%
_, dst1 = cv2.threshold(src, 100, 255, cv2.THRESH_BINARY)
_, dst2 = cv2.threshold(src, 210, 255, cv2.THRESH_BINARY)

# %%
cv2.imshow('src', src)
cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
def on_threshold(pos):
    _, dst = cv2.threshold(src, pos, 255, cv2.THRESH_BINARY)
    cv2.imshow('dst', dst)

# %%
cv2.imshow('src', src)
cv2.namedWindow('dst')
cv2.createTrackbar('Threshold', 'dst', 0, 255, on_threshold)
cv2.setTrackbarPos('Threshold', 'dst', 128)

cv2.waitKey()
cv2.destroyAllWindows()
