# %% [markdown]
# ![image.png](attachment:9b5a7e6e-effb-4dd0-8b1a-d2463f88e1e4.png)

# %% [markdown]
# ![image.png](attachment:27d4a63f-7d01-4e8d-bd61-16f5e321b657.png)

# %%
import sys
import numpy as np
import cv2

# %%
src = cv2.imread('../data/rice.png', cv2.IMREAD_GRAYSCALE)

if src is None:
    print('Image load failed!')
    sys.exit()

# %%
# 전역 이진화
_, dst1 = cv2.threshold(src,0,255,cv2.THRESH_BINARY| cv2.THRESH_OTSU)

# %%
# 지역 이진화
dst2 = np.zeros(src.shape, np.uint8)

bw = src.shape[1] // 4
bh = src.shape[0] // 4
bw, bh
# Out:
# (128, 128)

# %%
for y in range(4):
    for x in range(4):
        src_ = src[y*bh:(y+1)*bh,x*bw:(x+1)*bw]
        dst_ = dst2[y*bh:(y+1)*bh,x*bw:(x+1)*bw]
        cv2.threshold(src_, 0 , 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU, dst_)

# %%
cv2.imshow('src', src)
cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.waitKey()
cv2.destroyAllWindows()
