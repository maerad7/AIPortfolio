# %% [markdown]
# ![image.png](attachment:073f22ea-8157-4c97-af2b-1c2986d3fcec.png)

# %% [markdown]
# ![image.png](attachment:03966388-892f-434c-9e57-4b3ef2795333.png)

# %% [markdown]
# ![image.png](attachment:86ecaf9c-1fd5-49a2-a782-914e75ffbcd1.png)

# %% [markdown]
# ![image.png](attachment:f035145c-c9d9-446e-82de-5fa3358bedac.png)

# %% [markdown]
# ![image.png](attachment:5d28ff02-e48e-4bd2-b00d-7681b1ecb586.png)

# %% [markdown]
# ## 계층정보 사용

# %%
import sys
import random
import numpy as np
import cv2

# %%
src = cv2.imread('../data/contours.bmp', cv2.IMREAD_GRAYSCALE)

if src is None:
    print('Image load failed!')
    sys.exit()

# %%
contours, hier = cv2.findContours(src, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)

# %%
dst = cv2.cvtColor(src,cv2.COLOR_GRAY2BGR)

# %%
idx = 0

# %%
while idx >= 0:
    c = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
    cv2.drawContours(dst,contours,idx,c,2,cv2.LINE_8,hier)
    idx = hier[0, idx, 0]

# %%
cv2.imshow('src', src)
cv2.imshow('dst', dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## 계층정보 비사용

# %%
src = cv2.imread("../data/milkdrop.bmp", cv2.IMREAD_GRAYSCALE)

if src is None:
    print('Image load failed')
    sys.exit()

# %%
_, src_bin = cv2.threshold(src, 0, 255, cv2.THRESH_OTSU)

# %%
contours, _ = cv2.findContours(src_bin, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

# %%
h, w = src.shape[:2]

# %%
dst = np.zeros((h,w,3), np.uint8)

# %%
for i in range(len(contours)):
    c = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
    cv2.drawContours(dst, contours, i, c, 1, cv2.LINE_AA)

# %%
cv2.imshow('src', src)
cv2.imshow('src_bin', src_bin)
cv2.imshow('dst', dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 다양한 외곽선 함수

# %% [markdown]
# ![image.png](attachment:af5621cb-f798-4fe4-b880-2a8793f7f343.png)

# %% [markdown]
# ![image.png](attachment:efee1bc1-fe17-41fb-8e4f-fab05eb258f3.png)

# %% [markdown]
# ![image.png](attachment:c1d9359c-ed84-414c-9dfa-58d8be30fa48.png)

# %% [markdown]
# ![image.png](attachment:fde956cc-4013-4c09-ba5e-b11d898321e4.png)

# %% [markdown]
# ![image.png](attachment:bc65219b-530c-4a33-8e0d-953837147cb7.png)

# %% [markdown]
# ![image.png](attachment:93905e78-43e2-4612-9ec8-7b9eb35db06c.png)
