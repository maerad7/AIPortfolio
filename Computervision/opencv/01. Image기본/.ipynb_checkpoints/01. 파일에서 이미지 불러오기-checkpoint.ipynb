# %%
import argparse
import cv2
import matplotlib.pyplot as plt

# %%
params = '../data/Lena.png'
img = cv2.imread(params)

# %%
print('read {}'.format(params))
print('shape:', img.shape)
print('dtype:', img.dtype)
# Out:
# read ../data/Lena.png
# shape: (512, 512, 3)
# dtype: uint8

# %%
plt.imshow(img)

# %%
img = cv2.imread(params,cv2.IMREAD_GRAYSCALE)
print('read {}'.format(params))
print('shape:', img.shape)
print('dtype:', img.dtype)
# Out:
# read ../data/Lena.png
# shape: (512, 512)
# dtype: uint8

# %%
cv2.imshow('img',img)
cv2.waitKey(200)
# Out:
# -1

# %%
plt.imshow(img)
