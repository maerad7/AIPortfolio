# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../data/scenetext01.jpg')

# %%
det = cv2.text.TextDetectorCNN_create("../data/textbox.prototxt", "../data/TextBoxes_icdar13.caffemodel")
rects, probs = det.detect(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-524a2a627218> in <module>
# ----> 1 det = cv2.text.TextDetectorCNN_create("../data/textbox.prototxt", "../data/TextBoxes_icdar13.caffemodel")
#       2 rects, probs = det.detect(img)
#
# AttributeError: module 'cv2.cv2' has no attribute 'text'

# %%
THR = 0.3
for i, r in enumerate(rects):
    if probs[i] > THR:
        cv2.rectangle(img, (r[0], r[1]), (r[0]+r[2], r[1]+r[3]), (0, 255, 0), 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cab1a3f6a4c0> in <module>
#       1 THR = 0.3
# ----> 2 for i, r in enumerate(rects):
#       3     if probs[i] > THR:
#       4         cv2.rectangle(img, (r[0], r[1]), (r[0]+r[2], r[1]+r[3]), (0, 255, 0), 2)
#
# NameError: name 'rects' is not defined

# %%
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(img[:,:,[2,1,0]])
plt.tight_layout()
plt.show()
