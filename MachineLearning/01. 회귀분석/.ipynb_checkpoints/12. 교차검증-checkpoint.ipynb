# %% [markdown]
# # 교차검증

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import statsmodels.api as sm

boston = load_boston()
dfX = pd.DataFrame(boston.data, columns=boston.feature_names)
dfy = pd.DataFrame(boston.target, columns=['MEDV'])
df = pd.concat([dfX,dfy], axis = 1)

# cross validation
N = len(df)
ratio = 0.7
np.random.seed(0)

# 0~N 까지 N * 0.7 개 선택
idx_train = np.random.choice(np.arange(N),np.int(ratio*N))
idx_test = list(set(np.arange(N)).difference(idx_train))

df_train = df.iloc[idx_train]
df_test = df.iloc[idx_test]

# %%
df_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 172  0.13914   0.0   4.05   0.0  0.510  ...  296.0     16.6  396.90  14.69  23.1
# 47   0.22927   0.0   6.91   0.0  0.448  ...  233.0     17.9  392.74  18.80  16.6
# 117  0.15098   0.0  10.01   0.0  0.547  ...  432.0     17.8  394.51  10.30  19.2
# 192  0.08664  45.0   3.44   0.0  0.437  ...  398.0     15.2  390.49   2.87  36.4
# 323  0.28392   0.0   7.38   0.0  0.493  ...  287.0     19.6  391.13  11.74  18.5
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 80   0.04113  25.0   4.86   0.0  0.426  ...  281.0     19.0  396.90   5.29  28.0
# 446  6.28807   0.0  18.10   0.0  0.740  ...  666.0     20.2  318.01  17.79  14.9
# 136  0.32264   0.0  21.89   0.0  0.624  ...  437.0     21.2  378.25  16.90  17.4
# 189  0.08370  45.0   3.44   0.0  0.437  ...  398.0     15.2  396.90   5.39  34.9
# 129  0.88125   0.0  21.89   0.0  0.624  ...  437.0     21.2  396.90  18.34  14.3
#
# [354 rows x 14 columns]

# %%
df_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# 5    0.02985   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.12   5.21  28.7
# 6    0.08829  12.5   7.87   0.0  0.524  ...  311.0     15.2  395.60  12.43  22.9
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 499  0.17783   0.0   9.69   0.0  0.585  ...  391.0     19.2  395.77  15.10  17.5
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
#
# [255 rows x 14 columns]

# %%
model = sm.OLS.from_formula("MEDV ~" + "+".join(boston.feature_names), data=df_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     81.31
# Date:                Wed, 08 Jul 2020   Prob (F-statistic):           7.22e-96
# Time:                        09:31:28   Log-Likelihood:                -1057.6
# No. Observations:                 354   AIC:                             2143.
# Df Residuals:                     340   BIC:                             2197.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     40.6105      6.807      5.966      0.000      27.222      53.999
# CRIM          -0.0801      0.040     -2.012      0.045      -0.158      -0.002
# ZN             0.0438      0.016      2.777      0.006       0.013       0.075
# INDUS          0.0978      0.076      1.287      0.199      -0.052       0.247
# CHAS           2.7905      1.120      2.491      0.013       0.587       4.994
# NOX          -21.4614      4.919     -4.363      0.000     -31.136     -11.787
# RM             3.7948      0.532      7.128      0.000       2.748       4.842
# AGE            0.0006      0.016      0.036      0.971      -0.030       0.031
# DIS           -1.6910      0.256     -6.605      0.000      -2.195      -1.187
# RAD            0.2730      0.079      3.447      0.001       0.117       0.429
# TAX           -0.0097      0.004     -2.215      0.027      -0.018      -0.001
# PTRATIO       -1.1651      0.167     -6.983      0.000      -1.493      -0.837
# B              0.0134      0.004      3.815      0.000       0.006       0.020
# LSTAT         -0.5490      0.062     -8.908      0.000      -0.670      -0.428
# ==============================================================================
# Omnibus:                      129.426   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              603.605
# Skew:                           1.498   Prob(JB):                    8.49e-132
# Kurtosis:                       8.652   Cond. No.                     1.64e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pred = result.predict(df_test)

rss = ((df_test.MEDV - pred)**2).sum()
tss = ((df_test.MEDV - df_test.MEDV.mean())**2).sum()

rsquared = 1 - rss/tss
rsquared
# Out:
# 0.6883734124987108

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
df_train.shape, df_test.shape
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# ((354, 14), (152, 14))

# %%
dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(dfX, dfy, test_size = 0.3, random_state = 0)
df_train.shape, dfy_train.shape, dfX_test.shape, dfy_test.shape
# Out:
# ((354, 14), (354, 1), (152, 13), (152, 1))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state = 0)

for i, (idx_train,idx_test) in enumerate(cv.split(df)):
    df_train = df.iloc[idx_train]
    df_test = df.iloc[idx_test]
    
    model = sm.OLS.from_formula("MEDV ~" + "+".join(boston.feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.MEDV - pred)**2).sum()
    tss = ((df_test.MEDV - df_test.MEDV.mean())**2).sum()
    rsquared = 1 - rss/tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.77301356, 검증 R2 = 0.58922238
# 학습 R2 = 0.72917058, 검증 R2 = 0.77799144
# 학습 R2 = 0.74897081, 검증 R2 = 0.66791979
# 학습 R2 = 0.75658611, 검증 R2 = 0.66801630
# 학습 R2 = 0.70497483, 검증 R2 = 0.83953317

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.metrics import r2_score

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df)):
    df_train = df.iloc[idx_train]
    df_test = df.iloc[idx_test]
    
    model = sm.OLS.from_formula("MEDV ~ " + "+".join(boston.feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rsquared = r2_score(df_test.MEDV, pred)
    
    scores[i] = rsquared

scores
# Out:
# array([0.58922238, 0.77799144, 0.66791979, 0.6680163 , 0.83953317])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self,formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
    
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX,dfy], axis=1)
        self.model = smf.ols(self.formula, data = self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("MEDV ~" + "+".join(boston.feature_names))
cv = KFold(5, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2" , cv= cv)
# Out:
# array([0.58922238, 0.77799144, 0.66791979, 0.6680163 , 0.83953317])
