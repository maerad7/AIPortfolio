# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### 데이터 만들기

# %%
x_data = np.array([8759, 10132,12078,16430])
y_data = np.array([487, 612,866,1030])

plt.scatter(x_data,y_data, color = 'r', marker="s")
plt.show()

# %%
weight_0 = np.random.sample(5)
weight_1 = np.random.sample(5)

weight_0, weight_1
# Out:
# (array([0.31396334, 0.84307653, 0.64057224, 0.30227719, 0.92999886]),
#  array([0.75841604, 0.3796132 , 0.2458101 , 0.8465278 , 0.51737259]))

# %%
y_hat_list = []
for w0, w1 in zip(weight_0,weight_1):
    y_hat_list.append(w0 + w1*x_data)
y_hat_list
# Out:
# [array([ 6643.2800205 ,  7684.58523759,  9160.46284316, 12461.08943076]),
#  array([3325.87512823, 3847.08405699, 4585.8113515 , 6237.88801425]),
#  array([2153.69124609, 2491.18851463, 2969.53497099, 4039.30053014]),
#  array([ 7415.0392864 ,  8577.32195721, 10224.66505802, 13908.75404809]),
#  array([4532.59648062, 5242.94904135, 6249.75609393, 8501.3615887 ])]

# %%
plt.scatter(x_data,y_data, color = 'r', marker="s")
for y_hat in y_hat_list:
    plt.plot(x_data, y_hat)

plt.show()

# %%
y_hat[0] - y_data
# Out:
# array([4045.59648062, 3920.59648062, 3666.59648062, 3502.59648062])

# %% [markdown]
# #### MSE
# * MSE는 (y_hat -y_data)제곱 합에서 데이터의 개수로 나눈 값이다

# %%
sum ( (y_hat - y_data) ** 2 )/5
# Out:
# 24523722.715119075
