# %%
# !pip install requests

# %%
# !conda list requests
# Out:
# # packages in environment at C:\Users\p\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# requests                  2.18.4           py36h4371aae_1

# %%
import requests

# %%
url = 'https://ko.wikipedia.org/wiki/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.encoding
# Out:
# 'UTF-8'

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="ko" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>인공지능 - 위키백과, 우리 모두의 백과사전</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"인공지능","wgTitle":"인공지능","wgCurRevisionId":22652014,"wgRevisionId":22652014,"wgArticleId":104257,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["영어 표기를 포함한 문서","출처가 필요한 글/2018년 10월","출처가 필요한 모든 글","문단에 출처가 필요한 글","모호한 표현이 구체적으로 지적된 문서","LCCN 식별자를 포함한 위키백과 문서","GND 식별자를 포함한 위키백과 문서","BNF 식별자를 포함한 위키백과 문서","인공지능","사이버네틱스","형식과학","기술과 사회","계산 신경과학","이머징 테크놀로지","컴퓨터 과학의 미해결 문제"],"wgBreakFrames":false,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransformT
# ...

# %%
import lxml.html,cssselect

# %%
# !pip install cssselect

# %%
# !conda list lxml
# Out:
# # packages in environment at C:\Users\p\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# lxml                      4.2.1            py36heafd4d3_0

# %%
element = lxml.html.fromstring(res.text)

# %%
element
# Out:
# <Element html at 0x165a4c4d728>

# %%
heading = element.cssselect('#firstHeading')
heading
# Out:
# [<Element h1 at 0x165a1218ef8>]

# %%
title = heading[0].text_content()
title
# Out:
# '인공지능'

# %%
목차 = element.cssselect('#toc > ul')
목차
# Out:
# [<Element ul at 0x165a1218868>]

# %%
len(목차)
# Out:
# 1

# %%
목차[0].text_content()
# Out:
# "\n1 철학적 관점의 인공지능\n\n1.1 강인공지능(strong AI, 범용인공지능, AGI)과 약인공지능(weak AI)\n\n1.1.1 강인공지능(범용인공지능)\n1.1.2 약인공지능\n1.1.3 강인공지능에 대한 철학적인 주장과 반론\n\n\n\n\n2 역사\n\n2.1 인공지능 이론의 발전\n2.2 인공지능의 탄생(1952-1956)\n\n2.2.1 인공두뇌학과 초기 신경 네트워크\n2.2.2 튜링 테스트\n2.2.3 게임 인공지능\n2.2.4 상징 추론과 논리 이론\n2.2.5 다트머스 컨퍼런스 1956년\xa0: AI의 탄생\n\n\n2.3 황금기(1956~1974년)\n\n2.3.1 작업들\n\n2.3.1.1 탐색 추리\n2.3.1.2 자연어 처리\n2.3.1.3 마이크로월드\n\n\n2.3.2 낙관론\n2.3.3 자금\n\n\n2.4 AI의 첫번째 암흑기(1974-1980)\n\n2.4.1 문제\n2.4.2 자금지원의 중단\n2.4.3 캠퍼스 전역의 비판들\n2.4.4 퍼셉트론과 연결망의 어두운 시대\n2.4.5 깔끔이\xa0: 논리, 프롤로그와 전문가 시스템\n2.4.6 지저분이\xa0: 프레임과 스크립트\n\n\n2.5 Boom 1980-1987\n\n2.5.1 전문가 시스템의 상승\n2.5.2 지식 혁명\n2.5.3 돈은 되돌아온다\xa0: 5세대 프로젝트\n2.5.4 신경망 이론의 복귀\n\n\n2.6 AI의 두번째 암흑기 1987-1993\n\n2.6.1 인공지능의 겨울\n2.6.2 몸통을 갖는 것의 중요성: Nouvellle AI and embodied reason\n\n\n2.7 AI 1993-현재\n\n2.7.1 Milestones and Moores' Law\n2.7.2 지능형 에이전트\n2.7.3 Victory of the neats\n2.7.4 AI behind the scenes\n2.7.5 HAL 9000은 어디에 있는가?\n2.7.6 인공지능과 4차 산업혁명\n\n\n2.8 실험적인 AI 연구\n\n\n3 인공지능
# ...

# %%
목차 = element.cssselect('#toc > ul >li')

# %%
len(목차)
# Out:
# 8

# %%
목차[0].text_content()
# Out:
# '1 철학적 관점의 인공지능\n\n1.1 강인공지능(strong AI, 범용인공지능, AGI)과 약인공지능(weak AI)\n\n1.1.1 강인공지능(범용인공지능)\n1.1.2 약인공지능\n1.1.3 강인공지능에 대한 철학적인 주장과 반론\n\n\n\n'

# %%
목차[1].text_content()
# Out:
# "2 역사\n\n2.1 인공지능 이론의 발전\n2.2 인공지능의 탄생(1952-1956)\n\n2.2.1 인공두뇌학과 초기 신경 네트워크\n2.2.2 튜링 테스트\n2.2.3 게임 인공지능\n2.2.4 상징 추론과 논리 이론\n2.2.5 다트머스 컨퍼런스 1956년\xa0: AI의 탄생\n\n\n2.3 황금기(1956~1974년)\n\n2.3.1 작업들\n\n2.3.1.1 탐색 추리\n2.3.1.2 자연어 처리\n2.3.1.3 마이크로월드\n\n\n2.3.2 낙관론\n2.3.3 자금\n\n\n2.4 AI의 첫번째 암흑기(1974-1980)\n\n2.4.1 문제\n2.4.2 자금지원의 중단\n2.4.3 캠퍼스 전역의 비판들\n2.4.4 퍼셉트론과 연결망의 어두운 시대\n2.4.5 깔끔이\xa0: 논리, 프롤로그와 전문가 시스템\n2.4.6 지저분이\xa0: 프레임과 스크립트\n\n\n2.5 Boom 1980-1987\n\n2.5.1 전문가 시스템의 상승\n2.5.2 지식 혁명\n2.5.3 돈은 되돌아온다\xa0: 5세대 프로젝트\n2.5.4 신경망 이론의 복귀\n\n\n2.6 AI의 두번째 암흑기 1987-1993\n\n2.6.1 인공지능의 겨울\n2.6.2 몸통을 갖는 것의 중요성: Nouvellle AI and embodied reason\n\n\n2.7 AI 1993-현재\n\n2.7.1 Milestones and Moores' Law\n2.7.2 지능형 에이전트\n2.7.3 Victory of the neats\n2.7.4 AI behind the scenes\n2.7.5 HAL 9000은 어디에 있는가?\n2.7.6 인공지능과 4차 산업혁명\n\n\n2.8 실험적인 AI 연구\n\n"

# %%
목차 = element.xpath('//*[@id="firstHeading"]')
목차
# Out:
# [<Element h1 at 0x165a1218ef8>]

# %%
url = 'http://www.gevolution.co.kr/score/gamescore.asp?t=3&m=0&d=week'

# %%
res = requests.post(url, data= {'txtPeriodW' : '2017-12-30'})

# %%
res
# Out:
# <Response [200]>

# %%
res.encoding
# Out:
# 'UTF-8'

# %%
element = lxml.html.fromstring(res.text)

# %%
titles = element.cssselect('.tracktitle')

# %%
len(titles)
# Out:
# 100

# %%
[t.text_content() for t in titles[:10]]
# Out:
# ['리니지2 레볼루션',
#  '테라M',
#  '오버히트',
#  '세븐나이츠 for Kakao',
#  '소녀전선',
#  '클래시 로얄',
#  '프렌즈마블 for kakao',
#  '액스(AxE)',
#  '모두의마블 for kakao',
#  '서머너즈 워: 천공의 아레나']

# %%
res.encoding = 'UTF-8'

# %%
res.encoding
# Out:
# 'UTF-8'

# %%
url ='https://www.onoffmix.com/'

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [403]>

# %% [markdown]
# ### http://useragentstring.com
# * 브라우저 설명

# %%
header = { 'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36'}

# %%
res =requests.get(url,headers = header)

# %%
res
# Out:
# <Response [200]>

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
drive = webdriver.Chrome()

# %%
drive.get('https://www.naver.com')

# %%
btn = drive.find_element_by_css_selector('#account > div > a > i')
btn.click()

# %%
naver_id = drive.find_element_by_id('id')
naver_pw = drive.find_element_by_id('pw')

# %%
naver_id.send_keys('maerad7')
naver_pw.send_keys('akdpfkem1183!')

# %%
btn = drive.find_element_by_css_selector('#frmNIDLogin > fieldset > input')
btn.click()
